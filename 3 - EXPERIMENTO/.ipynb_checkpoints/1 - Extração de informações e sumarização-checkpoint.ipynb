# %% [markdown]
# # 📄 Extração de Informações e Sumarização de Processos
#
# Este notebook tem como objetivo Extrair informações relevantes de textos jurídicos (ex: descrição do caso, questões em discussão, soluções, teses).

# %%
import os
import requests
from dotenv import load_dotenv
import json
import time
from IPython.display import clear_output
from transformers import AutoTokenizer
import re
import psycopg2
import pandas as pd
from datetime import datetime, date  # Importando as classes datetime e date corretamente
import numpy as np

#Configurando certificado digital
certificados_serpro = ""
os.environ["REQUESTS_CA_BUNDLE"] = certificados_serpro
os.environ["SSL_CERT_FILE"] = certificados_serpro

# %%
# Conexão
def get_connection():
    return psycopg2.connect(
        dbname="PROCESSOS",
        user="postgres",
        password="",
        host="",
        port="5432"
    )

# %%
#dados para autenticação
client_id = ''
client_secret = ''

# %%
import requests 

data = {"grant_type":"client_credentials"}
url = "..."
result = requests.request('POST',url, data=data, auth=(client_id,client_secret))

# %%
# Variáveis globais para armazenar o token e o horário em que foi gerado
token = None
last_token_time = 0

# Função para obter o token da API
def get_token():
    client_id = ''
    client_secret = ''
    result = requests.request('POST', 
        "...", 
        #"https://e-api-serprollm.ni.estaleiro.serpro.gov.br/token",
        data={"grant_type":"client_credentials"}, 
        auth=(client_id, client_secret))

    if result.ok:
        return result.json()['access_token']
    else:
        raise Exception("Erro ao obter o token")

# Função para verificar se o token está expirado (renova se necessário)
def get_valid_token():
    global token, last_token_time
    current_time = time.time()
    
    # Se o token não existe ou já passaram mais de 20 minutos, obtemos um novo
    if token is None or (current_time - last_token_time) > 20 * 60:  # 20 minutos em segundos
        token = get_token()
        last_token_time = current_time
        print("Novo token obtido.")

    return token

# Função para invocar o LLM
def invoke(prompt, modelo,token, temperature=0, max_tokens=10000, stream=False):
    # Obtém o token válido (renova se necessário)
    

    payload_data = {
        "model": modelo,
        "messages": [{"role": "user", "content": prompt}],
        "temperature": temperature,
        "max_tokens": max_tokens,
        "stream": stream
    }

    result = requests.request("POST", 
        '...', 

        data=json.dumps(payload_data), 
        headers={
            "Authorization": f"Bearer {token}", 
            "Content-Type":"application/json"})

    if result.ok:
        res = result.json()
        resposta = res["choices"][0]["message"]['content']
        return resposta
    else:
        print(result.text)

# %%
def montar_prompt(ementa):
    prompt = f"""### INSTRUÇÕES ###
Você atua como um assistente jurídico com expertise em tornar ementas judiciais complexas mais compreensíveis, utilizando linguagem clara e acessível. Sua atuação está alinhada com as diretrizes estabelecidas pelo Pacto Nacional do Judiciário pela Linguagem Simples, iniciativa do Conselho Nacional de Justiça (CNJ).
Sua tarefa é transformar o texto em uma resposta clara, direta e fácil de entender por qualquer pessoa.
Não introduza novas informações, hipóteses, argumentos, fundamentos jurídicos ou conclusões que não estejam expressamente contidos no texto fornecido e não realize inferências especulativas.
Responda exclusivamente em português. Siga exatamente os formatos indicados.

Com base na ementa fornecida, extraia os seguintes campos e retorne a resposta em formato JSON. 
Campos esperados:

- "descricao_caso": Resuma o que aconteceu no processo, explicando os principais fatos e o que foi pedido. Não cite nomes de pessoas ou empresas. Use até 300 palavras.
- "questoes_em_discussao": Liste os principais pontos discutidos no julgamento. Use até 300 palavras.
- "solucoes_propostas": Explique, de forma resumida, como o problema foi analisado ou resolvido. Use até 200 palavras.
- "decisao": Informe o resultado do processo. Use apenas uma das opções: "Aceito", "Negado", "Aceito parcialmente" ou "Em análise".
- "tese": Se houver, diga qual foi a ideia principal da decisão, como uma regra que pode ser usada em outros casos parecidos. Use até 100 palavras.
- "envolve_mei": Informe apenas "Sim" ou "Não" se o processo fala de forma clara que um Microempreendedor Individual (MEI) é autor ou réu. Se for só uma citação genérica ou indireta, responda "Não".
- "mei_do_processo": Se envolve_mei for "Sim", diga se o MEI é o "Autor" ou o "Réu". Se não der para saber claramente, escreva "Ninguém".

### Exemplo de resposta esperada:
```json
{{
  "descricao_caso": "Um MEI entrou com uma ação contra o município alegando cobrança indevida de taxas que não estavam previstas em lei.",
  "questoes_em_discussao": "Foi discutido se a cobrança tinha base legal e se era proporcional ao tipo de atividade do MEI.",
  "solucoes_propostas": "O tribunal entendeu que a cobrança era indevida por falta de previsão legal e por não ser proporcional à atividade.",
  "decisao": "Aceito",
  "tese": "O município não pode cobrar taxas de MEI sem base legal e proporcionalidade.",
  "envolve_mei": "Sim",
  "mei_do_processo": "Autor"
}}
---

### EMENTA ###
{ementa}
"""
    return prompt

# %%
def extrair():
    modelo = 'pixtral-12b'
    
    # Função com retry para pegar token
    def tentar_obter_token_com_retry(max_tentativas=5, espera_segundos=120):
        for tentativa in range(max_tentativas):
            try:
                return get_token()
            except Exception as e:
                print(f"❌ Erro ao obter token: {e}")
                if tentativa < max_tentativas - 1:
                    print(f"⏳ Aguardando {espera_segundos // 60} min para tentar novamente ({tentativa+1}/{max_tentativas})...")
                    time.sleep(espera_segundos)
                else:
                    print("⛔ Máximo de tentativas para obter token excedido.")
                    raise

    token = tentar_obter_token_com_retry()

    # Conectar e buscar processos pendentes de sumarização
    conn = get_connection()
    query = """ 
        SELECT id, numero_processo_tribunal, ementa_completa, qtd_tokens_ementa
        FROM processos 
        WHERE response IS NULL AND qtd_tokens_ementa > 150  and 
        (json_bem_formado is null or json_bem_formado = 0) 
        and numero_processo_tribunal not in ('00004773020205070025_TRT-7','22438250820078130223_TJ-MG', '5003570032014404710250035700320144047102_TRF-4','00002223020205070039_TRT-7')
        order by qtd_tokens_ementa ASC

    """
    df = pd.read_sql_query(query, conn)
    conn.close()

    total = len(df)
    print(f"Total de registros pendentes para {modelo}: {total}")

    for i, row in df.iterrows():
        print(f"{i+1}/{total}")
        processo = row['numero_processo_tribunal']
        print(f"Processo: {processo}")

        ementa = row['ementa_completa']
        prompt = montar_prompt(ementa)
        print(prompt)

        try:
            resposta_crua = invoke(prompt, modelo, token)

            # Remover delimitadores ```json ... ``` se existirem
            match = re.search(r"```json\s*(\{.*?\})\s*```", resposta_crua, re.DOTALL)
            if match:
                resposta = match.group(1).replace('\n', '').replace('  ', '').strip()
            else:
                resposta = resposta_crua.strip()

            clear_output(wait=True)
            print(resposta)

            # Atualizar banco
            conn = get_connection()
            cursor = conn.cursor()
            cursor.execute("""
                UPDATE processos
                SET response = %s
                WHERE id = %s
            """, (resposta, row['id']))
            conn.commit()
            cursor.close()
            conn.close()

        except Exception as e:
            print(f"❌ Erro ao processar processo {processo}: {e}")
            print("⏳ Aguardando 5 minutos antes de tentar o próximo...")
            #time.sleep(300)  # Espera 3 minutos antes de continuar
            token = tentar_obter_token_com_retry()  # Tenta obter novo token

# %%
while True:
    print("🟢 Iniciando extração...")
    extrair()
    print("⏳ Aguardando 10 minutos até a próxima extração...")
    time.sleep(600)
# Out:
# 🟢 Iniciando extração...
# C:\Users\Loreane\AppData\Local\Temp\ipykernel_20228\212120337.py:31: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)
# Total de registros pendentes para pixtral-12b: 8
# 1/8
# Processo: 1597163815971638_TJ-PR
# ### INSTRUÇÕES ###
# Você atua como um assistente jurídico com expertise em tornar ementas judiciais complexas mais compreensíveis, utilizando linguagem clara e acessível. Sua atuação está alinhada com as diretrizes estabelecidas pelo Pacto Nacional do Judiciário pela Linguagem Simples, iniciativa do Conselho Nacional de Justiça (CNJ).
# Sua tarefa é transformar o texto em uma resposta clara, direta e fácil de entender por qualquer pessoa.
# Não introduza novas informações, hipóteses, argumentos, fundamentos jurídicos ou conclusões que não estejam expressamente contidos no texto fornecido e não realize inferências especulativas.
# Responda exclusivamente em português. Siga exatamente os formatos indicados.
#
# Com base na ementa fornecida, extraia os seguintes campos e retorne a resposta em formato JSON.
# Campos esperados:
#
# - "descricao_caso": Resuma o que aconteceu no processo, explicando os principais fatos e o que foi pedido. Não cite nomes de pessoas ou empresas. Use até 300 palavras.
# - "questoes_em_discussao": Liste os principais pontos discutidos no julgamento. Use até 300 palavras.
# - "solucoes_propostas": Explique, de forma resumida, como o problema foi analisado ou resolvido. Use até 200 palavras.
# - "decisao": Informe o resultado do processo. Use apenas uma das opções: "Aceito", "Negado", "Aceito parcialmente" ou "Em análise".
# - "tese": Se houver, diga qual foi a ideia principal da decisão, como uma regra que pode ser usada em outros casos parecidos. Use até 100 palavras.
# - "envolve_mei": Informe apenas "Sim" ou "Não" se o processo fala de forma clara que um Microempreendedor Individual (MEI) é autor ou réu. Se for só uma citação genérica ou indireta, responda "Não".
# - "mei_do_processo": Se envolve_mei for "Sim", diga se o MEI é o "Autor" ou o "Réu". Se não der para saber claramente, escreva "Ninguém".
#
# ### Exemplo de resposta esperada:
# ```json
# {
#   "descricao_caso": "Um MEI entrou com uma ação contra o município alegando cobrança indevida de taxas que não estavam previstas em lei.",
#   "questoes_em_discussao": "Foi discutido se a cobrança tinha base legal e se era proporcional ao tipo de atividade do MEI.",
#   "solucoes_propostas": "O tribunal entendeu que a cobrança era indevida por falta de previsão legal e por não ser proporcional à atividade.",
#   "decisao": "Aceito",
#   "tese": "O município não pode cobrar taxas de MEI sem base legal e proporcionalidade.",
#   "envolve_mei": "Sim",
#   "mei_do_processo": "Autor"
# }
# ---
#
# ### EMENTA ###
# EmentaAPELAÇÕES CÍVEIS.AÇÃO CIVIL PÚBLICA POR ATOS DE IMPROBIDADE ADMINISTRATIVA. ESQUEMA DE "RODÍZIO LICITATÓRIO" NO MUNICÍPIO DE TAMARANA PARA FRAUDAR A COMPETITIVIDADE DE LICITAÇÕES PARA A CONTRATAÇÃO DE SERVIÇO DE TRANSPORTE ESCOLAR.SENTENÇA DE PARCIAL PROCEDÊNCIA.INCONSTITUCIONALIDADE MATERIAL DA LEI Nº8.429/1992.NÃO ACOLHIMENTO. A ABERTURA DOS TIPOS DE IMPROBIDADE ADMINISTRATIVA NÃO TORNA A LEI INCOMPATÍVEL COM OS PRINCÍPIOS DA PROPORCIONALIDADE, RAZOABILIDADE E SEGURANÇA JURÍDICA, DEVENDO A CONCRETIZAÇÃO DOS TIPOS SER FEITA ANALITICAMENTE NO CASO CONCRETO. O ROL DE SANÇÕES DO ART.37,§ 4º, DACONSTITUIÇÃO FEDERALNÃO É TAXATIVO, SENDO PERMITIDO AO LEGISLADOR PREVER OUTRAS PENALIDADES.ALEGAÇÃO DE ILICITUDE DA PROVA DOCUMENTAL JUNTADA POSTERIORMENTE PELO MINISTÉRIO PÚBLICO.NÃO ACOLHIMENTO. EMBORA A PROVA DOCUMENTAL, EM REGRA, DEVA SER TRAZIDA JUNTO COM A PETIÇÃO INICIAL, NÃO DEVE SER RECONHECIDA A NULIDADE DA JUNTADA POSTERIOR EM RAZÃO DA AUSÊNCIA DE PREJUÍZO. JUNTADA ANTES DA AUDIÊNCIA DE INSTRUÇÃO E JULGAMENTO, PERMITINDO AOS RÉUS QUE SE MANIFESTASSE INCLUSIVE ORALMENTE SOBRE A PROVA DOCUMENTAL. ARTIGOS435,PARÁGRAFO ÚNICO, DOCPC/2015E231DOCPP.RECURSOS DOS RÉUS.ALEGAÇÃO DE AUSÊNCIA DE PROVAS PARA EMBASAR A CONDENAÇÃO.NÃO ACOLHIMENTO.POSSIBILIDADEDE CONDENAÇÃO UNICAMENTE COM BASE EM INDÍCIOS (NA ACEPÇÃO DE PROVA INDIRETA, NOS TERMOS DO ART.239DOCPP), DESDE QUE SEJAM PLURAIS, CONCOMITANTES E UNIVOCAMENTE INCRIMINADORES. ENTENDIMENTO DEFENDIDO PELO STF NO JULGAMENTO DAAÇÃO PENAL Nº 470. IMPORTÂNCIA DOS INDÍCIOS EM RELAÇÃO AOS ILÍCITOS DE DIFÍCIL COMPROVAÇÃO, ESPECIALMENTE OS COMETIDOS DE FORMA ASSOCIATIVA, MEDIANTE A PARTICIPAÇÃO DE VÁRIAS PESSOAS E DENTRO DA ESTRUTURA ADMINISTRATIVA.PROVAS DOS AUTOS QUE DEMONSTRAM O FAVORECIMENTO DAS EMPRESAS DE JUHAD WEHBE AL CHAAR E GUSTAVO SEBASTIÃO DA SILVA, ALIADOS POLÍTICOS DO PREFEITO ROBERTO DIAS SIENA, EM DEZENAS DE LICITAÇÕES PROMOVIDAS PELO MUNICÍPIO DE TAMARANA PARA A CONTRATAÇÃO DO SERVIÇO DE TRANSPORTE ESCOLAR. PROVAS DE AJUSTE PRÉVIO DE PREÇOS E DISTRIBUIÇÃO DE LINHAS TAMBÉM COM A EMPRESA DE MARCELO CARLOS MANO.FRAUDE À COMPETITIVIDADE DO CERTAME.VIOLAÇÃO AOS PRINCÍPIO DE SIGILO DAS PROPOSTAS E DA IMPESSOALIDADE. PARTICIPAÇÃO DO PREFEITO MUNICIPAL, DO SECRETÁRIO DA FAZENDA E DEMAIS MEMBROS DA COMISSÃO DE LICITAÇÃO. DOUTRINA DA "CEGUEIRA DELIBERADA" APLICÁVEL AO PREFEITO MUNICIPAL. INDIFERENÇA CONSCIENTE DO ADMINISTRADOR PÚBLICO AOS VOLUMOSOS INDÍCIOS DE ILICITUDE QUE AFLORARAM DOS CERTAMES LICITATÓRIOS NO MUNICÍPIO DO PERÍODO DE 2005 A 2012.ALEGAÇÃO DE AUSÊNCIA DE DOLO E MÁ-FÉ.NÃO ACOLHIMENTO. ATUAÇÃO CONSCIENTE E DELIBERADA DOS RÉUS NO SENTIDO DE VIOLAR AS REGRAS DISCIPLINADORAS DA LICITAÇÃO PARA O FIM DE FAVORECER DETERMINADAS EMPRESAS.INDENIZAÇÃO POR DANOS MORAIS COLETIVOS.POSSIBILIDADE.JURISPRUDÊNCIA DO STJ.PRESCINDIBILIDADE DA COMPROVAÇÃO DE DOR, SOFRIMENTO OU ABALO PSICOLÓGICO, PRÓPRIOS DA ESFERA INDIVIDUAL.FATOS QUE GERARAM GRANDE IMPACTO NA COMUNIDADE DE TAMARANA.REITERAÇÃO E EXPRESSIVO IMPACTO FINANCEIRO.MANUTENÇÃO DA CONDENAÇÃO.PRESCRIÇÃO.INOCORRÊNCIA. O PRAZO PRESCRICIONAL SOMENTE COMEÇA A FLUIR DA CIÊNCIA DA VIOLAÇÃO DO DIREITO, EM DECORRÊNCIA DO PRINCÍPIO DA ACTIO NATA. CIÊNCIA PELA COMUNIDADE OCORRIDA SOMENTE NA EFETIVAÇÃO DA MEDIDA DE BUSCA E APREENSÃO, HAJA VISTA O CARÁTER SIMULADO DAS CONDUTAS.RECURSO DO MINISTÉRIO PÚBLICO.ALEGAÇÃO DE NÃO CONHECIMENTO POR OFENSA AO PRINCÍPIO DA DIALETICIDADE.NÃO ACOLHIMENTO.RAZÕES RECURSAIS QUE ATACAM DIRETAMENTE A SENTENÇA.INSURGÊNCIA QUANTO À ABSOLVIÇÃO DE 14 DOS 28 RÉUS. MANUTENÇÃO, POR AUSÊNCIA DE PROVAS, DA IMPROCEDÊNCIA DA PRETENSÃO EM RELAÇÃO AOS RÉUS ALDO BOARETTO NETTO, MARIA ROSE SOARES, REGINALDO ANDRÉ DE SOUZA E TÂNIA CRISTINA COELHO ARANDA. EMBORA HAJA LIAME ENTRE AS CONDUTAS DOS RÉUS E A PERPETRAÇÃO DO ESQUEMA ILÍCITO DENUNCIADO NA PETIÇÃO INICIAL, NÃO HÁ NOS AUTOS ELEMENTOS QUE EVIDENCIEM O DOLO DE VIOLAR NORMAS APLICÁVEIS À ADMINISTRAÇÃO PÚBLICA PARA ALCANCAR FINS ILÍCITOS, MOTIVO PELO QUAL NÃO É POSSÍVEL A COND ...
#
# {"object":"error","message":"max_tokens must be at least 1, got -4111.","type":"BadRequestError","param":null,"code":400}
# ❌ Erro ao processar processo 1597163815971638_TJ-PR: expected string or bytes-like object
# ⏳ Aguardando 5 minutos antes de tentar o próximo...
# 2/8
# Processo: 00012719720195200001_TRT-20
# ### INSTRUÇÕES ###
# Você atua como um assistente jurídico com expertise em tornar ementas judiciais complexas mais compreensíveis, utilizando linguagem clara e acessível. Sua atuação está alinhada com as diretrizes estabelecidas pelo Pacto Nacional do Judiciário pela Linguagem Simples, iniciativa do Conselho Nacional de Justiça (CNJ).
# Sua tarefa é transformar o texto em uma resposta clara, direta e fácil de entender por qualquer pessoa.
# Não introduza novas informações, hipóteses, argumentos, fundamentos jurídicos ou conclusões que não estejam expressamente contidos no texto fornecido e não realize inferências especulativas.
# Responda exclusivamente em português. Siga exatamente os formatos indicados.
#
# Com base na ementa fornecida, extraia os seguintes campos e retorne a resposta em formato JSON.
# Campos esperados:
#
# - "descricao_caso": Resuma o que aconteceu no processo, explicando os principais fatos e o que foi pedido. Não cite nomes de pessoas ou empresas. Use até 300 palavras.
# - "questoes_em_discussao": Liste os principais pontos discutidos no julgamento. Use até 300 palavras.
# - "solucoes_propostas": Explique, de forma resumida, como o problema foi analisado ou resolvido. Use até 200 palavras.
# - "decisao": Informe o resultado do processo. Use apenas uma das opções: "Aceito", "Negado", "Aceito parcialmente" ou "Em análise".
# - "tese": Se houver, diga qual foi a ideia principal da decisão, como uma regra que pode ser usada em outros casos parecidos. Use até 100 palavras.
# - "envolve_mei": Informe apenas "Sim" ou "Não" se o processo fala de forma clara que um Microempreendedor Individual (MEI) é autor ou réu. Se for só uma citação genérica ou indireta, responda "Não".
# - "mei_do_processo": Se envolve_mei for "Sim", diga se o MEI é o "Autor" ou o "Réu". Se não der para saber claramente, escreva "Ninguém".
#
# ### Exemplo de resposta esperada:
# ```json
# {
#   "descricao_caso": "Um MEI entrou com uma ação contra o município alegando cobrança indevida de taxas que não estavam previstas em lei.",
#   "questoes_em_discussao": "Foi discutido se a cobrança tinha base legal e se era proporcional ao tipo de atividade do MEI.",
#   "solucoes_propostas": "O tribunal entendeu que a cobrança era indevida por falta de previsão legal e por não ser proporcional à atividade.",
#   "decisao": "Aceito",
#   "tese": "O município não pode cobrar taxas de MEI sem base legal e proporcionalidade.",
#   "envolve_mei": "Sim",
#   "mei_do_processo": "Autor"
# }
# ---
#
# ### EMENTA ###
# Inteiro TeorJurisprudência PJe - TRT da 20ª regiãoPODER JUDICIÁRIOJUSTIÇA DO TRABALHOTRIBUNAL REGIONAL DO TRABALHO DA 20ª REGIÃOSegunda TurmaIDENTIFICAÇÃOPROCESSO nº0001271-97.2019.5.20.0001(ROT)RECORRENTE:ALESSANDRA ARAUJO PEREIRA RIBEIRO, NATURA COSMETICOS S/ARECORRIDO:ALESSANDRA ARAUJO PEREIRA RIBEIRO, NATURA COSMETICOS S/ARELATOR DESIGNADO:JORGE ANTONIO ANDRADE CARDOSOEMENTARECURSO ORDINÁRIO - RECONHECIMENTO DE VÍNCULO EMPREGATÍCIO - CONSULTORA ORIENTADORA NATURA / CONSULTORA LÍDER DE NEGÓCIOS - SUBORDINAÇÃO ESTRUTURAL - O Direito do Trabalho contemporâneo evoluiu o conceito da subordinação objetiva para o conceito de subordinação estrutural, a qual se manifesta pela inserção do trabalhador na dinâmica de organização e funcionamento da atividade econômica do tomador de seus serviços, pouco importando se recebe ou não ordens diretas deste. No caso dos autos, as provas demonstram que havia subordinação da reclamante à reclamada, notadamente porque ela era responsável por uma equipe de Consultoras da reclamada, sendo vinculada a uma gerente - reconhecidamente empregada da empresa -, com imposição de metas e atribuições claramente demarcadas e cobradas, sob pena de desligamento. Assim, tem-se que a Consultora Orientadora Natura/Consultora Líder de Negócios está inserida na dinâmica econômica da recorrida, como se fosse uma "longa manus" da empregadora, e não somente uma mera revendedora/consultora de seus produtos. Presentes os demais requisitos dos artigos2ºe3ºdaCLT, mantém-se a sentença que reconheceu a existência de vínculo empregatício da reclamante com a reclamada.RELATÓRIOALESSANDRA ARAUJO PEREIRA RIBEIRO, reclamante, e AVON COSMÉTICOS LTDA, reclamada, recorrem ordinariamente (ID. c777e4a e ID. 5d1a408, respectivamente), da sentença proferida pela 1ª Vara do Trabalho de Aracaju, que julgou procedentes, em parte, os pedidos formulados na reclamatória trabalhista em que litigam.Regularmente notificada, a reclamada apresentou razões de contrariedade ao ID. 507b43a e a reclamante ao ID. 9b8400d.Nos autos, foi designado Relator, originariamente, o DesembargadorJosé Augusto do Nascimento.Em sessão realizada em 05/10/2020, a Segunda Turma deste Regional, resolveu, por maioria, manter o vínculo empregatício entre a autora e reclamada, reconhecido em sentença; sendo vencido o Desembargador Relator, que afastava o referido vínculo.Existindo matérias que demandavam apreciação, em apelos de ambas as partes, cuja apreciação decorria da manutenção do vínculo, fui designado Relator deste processo, com os autos sendo encaminhados ao meu gabinete, para minuta atinente a essas matérias remanescentes; conforme certidão de ID. c139c58.FUNDAMENTAÇÃO1. ADMISSIBILIDADE1.1. DA PRELIMINAR DE "DESERÇÃO - SEGURO GARANTIA - NÃO CONHECIMENTO DO RECURSO ORDINÁRIO DA RÉ", SUSCITADA NAS CONTRARRAZÕES DA RECLAMANTERequer a reclamante que não seja conhecido o recurso da reclamada alegando a deserção, nestes termos:"Como depósito recursal, a Recorrente apresentou Apólice Seguro Garantia, colacionado aos autos sob o ID. 84ebbf2.Data vênia, não há como acolher o preparo na forma de seguro garantia, uma vez que se trata de documento emitido por terceiro estranho à lide e condicionada sua aceitação para pagamento segundo contrato de seguro.Ademais, a garantia do seguro por apólice não é efetiva, porque condicional tanto na necessidade de aceitação por parte do garantidor, bem como do efetivo pagamento, que pode ou não ser disponibilizado.O seguro garantia ainda vigora por prazo determinado e depende de renovação periódica, que pode ocorrer ou não. O mercado de seguro não desenvolveu apólice especifica que atenda a indeterminação da duração do processo judicial.Além disso, sequer houve comprovação de regularidade da apólice.Pelo exposto, não se pode atribuir ao Seguro Garantia Judicial a condição de substituto do depósito recursal, restando caracterizada a deserção do Recurso Ordinário interposto pela Ré.Portanto, requer o Recorrido que o Recurso Ordinário da  ...
